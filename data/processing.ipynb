# %%
import geopandas as gpd
import pandas as pd

# %%
province_mock = gpd.read_file("./test_data/province_border.geojson")
province_mock
# Out:
#     id  gid  province_c      name   type  \
# 0    1    1    110000.0       北京市    直辖市
# 1    2    2    120000.0       天津市    直辖市
# 2    3    3    130000.0       河北省      省
# 3    4    4    140000.0       山西省      省
# 4    5    5    150000.0    内蒙古自治区    自治区
# 5    6    6    150000.0      中朝共有    不统计
# 6    7    7    210000.0       辽宁省      省
# 7    8    8    220000.0       吉林省      省
# 8    9    9    230000.0      黑龙江省      省
# 9   10   10    310000.0       上海市    直辖市
# 10  11   11    320000.0       江苏省      省
# 11  12   12    330000.0       浙江省      省
# 12  13   13    340000.0       安徽省      省
# 13  14   14    350000.0       福建省      省
# 14  15   15    360000.0       江西省      省
# 15  16   16    370000.0       山东省      省
# 16  17   17    410000.0       河南省      省
# 17  18   18    420000.0       湖北省      省
# 18  19   19    430000.0       湖南省      省
# 19  20   20    440000.0       广东省      省
# 20  21   21    450000.0   广西壮族自治区    自治区
# 21  22   22    460000.0       海南省      省
# ...
